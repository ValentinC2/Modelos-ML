# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]

# %%
x = data[:, np.newaxis,5]
x_train, x_test, y_train, y_test = train_test_split(x, target)

# %%
model = RandomForestRegressor(n_estimators= 300 , max_depth=8)

model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=8, n_estimators=300)

# %%
predict = model.predict(x_test)
model.score(x_test, y_test)
# Out:
# 0.7278000391343457

# %%
x_m = np.arange(min(x_train), max(x_train), 0.1)
x_m = x_m.reshape(len(x_m), 1)

plt.scatter(x_train, y_train)
plt.scatter(x_test, y_test, color='g')
plt.plot(x_m, model.predict(x_m), color='r')
